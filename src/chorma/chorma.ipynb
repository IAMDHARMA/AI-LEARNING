# %%
pip install chromadb
# Out:
# r:\AI Engineer\.venv\Scripts\python.exe: No module named pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import chromadb

chormadb_client = chromadb.Client()

collection = chormadb_client.create_collection(name="my_collection")



collection.add(
    ids= ["id1","id2"],
    documents=[
        "i am dharmarajan",
        "i from trichy"
    ]
)
print(collection[0])
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[24], line 5
#       1 import chromadb
#       3 chormadb_client = chromadb.Client()
# ----> 5 collection = chormadb_client.create_collection(name="my_collection")
#       9 collection.add(
#      10     ids= ["id1","id2"],
#      11     documents=[
#    (...)     14     ]
#      15 )
#      16 print(collection[0])
#
# File r:\AI Engineer\.venv\Lib\site-packages\chromadb\api\client.py:222, in Client.create_collection(self, name, schema, configuration, metadata, embedding_function, data_loader, get_or_create)
#     219 if embedding_function is not None and configuration_ef is None:
#     220     configuration["embedding_function"] = embedding_function
# --> 222 model = self._server.create_collection(
#     223     name=name,
#     224     schema=schema,
#     225     metadata=metadata,
#     226     tenant=self.tenant,
#     227     database=self.database,
#     228     get_or_create=get_or_create,
#     229     configuration=configuration,
#     230 )
#     231 return Collection(
#     232     client=self._server,
#     233     model=model,
#     234     embedding_function=embedding_function,
#     235     data_loader=data_loader,
#     236 )
#
# File r:\AI Engineer\.venv\Lib\site-packages\chromadb\api\rust.py:244, in RustBindingsAPI.create_collection(self, name, schema, configuration, metadata, get_or_create, tenant, database)
#     241 else:
#     242     schema_str = None
# --> 244 collection = self.bindings.create_collection(
#     245     name,
#     246     configuration_json_str,
#     247     schema_str,
#     248     metadata,
#     249     get_or_create,
#     250     tenant,
#     251     database,
#     252 )
#     253 collection_model = CollectionModel(
#     254     id=collection.id,
#     255     name=collection.name,
#    (...)    261     database=collection.database,
#     262 )
#     263 return collection_model
#
# InternalError: Collection [my_collection] already exists
