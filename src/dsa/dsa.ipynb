# %%
print("hi")
# Out:
# hi

# %%
my_list = [1, 3, 5, 7, 9 , 11,12,13,14]
#target 3 and 7

def binary_search(user_list,target):
    low = 0
    high = len(user_list)-1

    while low <= high:
        mid = (low+high)//2
        gusess = user_list[mid]
        if gusess == target:
            return mid
        if gusess > target:
             high =mid - 1
        else:
            low = mid +1
    return None

print(binary_search(my_list,13))
# Out:
# 7

# %%
names = [f"names{i}" for i in range(1,129)]
names
# i want to find names37
def find_name(sr_name,target):
    start = 0
    end = len(sr_name)-1
    while start <= end:
        mid = (start+end)//2
        guess = sr_name[mid]
        if guess == target:
            return mid
        if guess > target:
            end = mid - 1
        else:
            end = mid + 1
    return None

find_name(names,"names32")
# Out:
# 31
